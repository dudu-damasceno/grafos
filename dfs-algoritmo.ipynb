# %%
def DepthFirstSearch(listaAdj, atual, visitados = []):
    if atual not in visitados:
        visitados.append(atual)

        for i in listaAdj[atual]:
            if i not in visitados:
                DepthFirstSearch(listaAdj, i, visitados)
        return visitados

def DFS(listaAdj, Vi):
    visitados = DepthFirstSearch(listaAdj, Vi)

    print(visitados)
